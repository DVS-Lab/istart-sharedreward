# %%
import os
import numpy as np
import pandas as pd
import re
import scipy.stats as stats
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import AnovaRM
from sklearn.linear_model import LinearRegression
import csv

workingdir = os.getcwd()
usedir = workingdir + '/../derivatives'
os.chdir(usedir)

ppi_df = pd.read_excel("ppi_wholebrain_scatterplot.xls")
SR_flist=[os.path.join(root, f) for root, dirs, files in os.walk('logs') for f in files if 'SR-Rating' in f]

# %% [markdown]
# # Setting up dataframes

# %%
temp = ppi_df
ASRD = pd.read_csv('../../istart/Shared_Reward/Behavioral_Analysis/Data_Out/AllSharedRewardData.csv')
APD = pd.read_excel('ISTART-ALL-Combined-042122.xlsx')
keepios = [col for col in APD.columns if col.startswith('ios') or col.startswith('sub')]
keepwinlose = [col for col in ASRD.columns if col.startswith('Win') or col.startswith('Lose') or col.startswith('sub')]
temp1 = pd.merge(APD[['sub','dudit_drugtype','audit_standard_score']], temp, on='sub', how = 'right')
temp2 = pd.merge(APD[keepios], temp1, on = 'sub', how = 'right')
temp3 = pd.merge(ASRD[keepwinlose], temp2, on='sub', how='right')
temp999 = temp3.drop_duplicates(subset=['Subject']).dropna(subset=['Subject'])

df = temp999.replace(999, np.NaN)

#creates difference scores for contrast between IOS closeness rating for each partner
df['ios_p']
df['ios_diff_computer'] = df['ios_p'] - df['ios_computer'] #ios_p was participant rating of frend, ios_fu was participant rating of stranger in follow-up. ios_f was FRIEND rating of participant
df['ios_diff_stranger'] = df['ios_p'] - df['ios_fu_score']
df['ios_diff_fu'] = df['ios_fu_score'] - df['ios_computer']

#creates difference scores for contrast between post-scan partner rating for each partner
df['Win_F_C'] = df['Win-Friend'] - df['Win-Comp']
df['Win_F_S'] = df['Win-Friend'] - df['Win-Stranger']
df['Diff_Friend'] = df['Win-Friend'] - df['Lose-Friend']
df['Diff_Stranger'] = df['Win-Stranger'] - df['Lose-Stranger']
df['Diff_Comp'] = df['Win-Comp'] - df['Lose-Comp']
df['Win_Lose_F_S'] = df['Diff_Friend'] - df['Diff_Stranger']
df['Win_Lose_F_C'] = df['Diff_Friend'] - df['Diff_Comp']

#creates difference scores for each contrast using pre-registered TPJ target activation extracted from whole-brain ppi analysis with VS seed
df['aTPJ_R_P_F_C'] = (df['aTPJ_VS_ppi_cope_04'] - df['aTPJ_VS_ppi_cope_03']) - (df['aTPJ_VS_ppi_cope_02'] - df['aTPJ_VS_ppi_cope_01'])
df['aTPJ_R_P_F_S'] = (df['aTPJ_VS_ppi_cope_04'] - df['aTPJ_VS_ppi_cope_03']) - (df['aTPJ_VS_ppi_cope_06'] - df['aTPJ_VS_ppi_cope_05'])
df['pTPJ_R_F_S'] = (df['pTPJ_VS_ppi_cope_04'] - df['pTPJ_VS_ppi_cope_06'])
df['pTPJ_R_P_F_C'] = (df['pTPJ_VS_ppi_cope_04'] - df['pTPJ_VS_ppi_cope_03']) - (df['pTPJ_VS_ppi_cope_02'] - df['pTPJ_VS_ppi_cope_01'])
df['pTPJ_R_P_F_S'] = (df['pTPJ_VS_ppi_cope_04'] - df['pTPJ_VS_ppi_cope_03']) - (df['pTPJ_VS_ppi_cope_06'] - df['pTPJ_VS_ppi_cope_05'])

#dataframes sans NaNs
df_ios = df.dropna(subset=['ios_diff_computer'])
df_psr = df.dropna(subset = ['Win_F_S'])
df_both = df_psr.dropna(subset=['ios_diff_computer'])

pd.set_option('display.max_columns',None,'display.max_rows', None)

# %% [markdown]
# # Correlation Matrix for all data

# %%
rho = df.corr()
pval = df.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [.001, .01, .05] if x<=t]))
cormat = rho.round(2).astype(str) + p
display(cormat)

fig = plt.figure(figsize=(12, 8))
sns.heatmap(rho,cmap='vlag',vmin=-1)
plt.show()
# Out:
# C:\Users\tup54227\Anaconda3\lib\site-packages\scipy\stats\_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
#                                                        sub Win-Friend  \
# sub                                                 1.0***       0.21
# Win-Friend                                            0.21     1.0***
# Win-Stranger                                          0.02      0.37*
# Win-Comp                                             -0.06       0.18
# Lose-Friend                                          -0.26     -0.36*
# Lose-Stranger                                        -0.11      -0.19
# Lose-Comp                                             0.03       -0.1
# ios_fu_score                                           0.3       0.12
# ios_computer                                        0.52**       0.17
# ios_f                                                -0.11       0.13
# ios_p                                                 0.23       0.26
# audit_standard_score                                 -0.22      -0.09
# Subject                                             1.0***       0.21
# Ones                                                   nan        nan
# SU                                                    0.03       0.02
# RS                                                   -0.01        0.2
# RS_square                                             0.02       0.21
# SUxRS                                                 0.02       0.04
# SUxRS_sq                                             -0.23       0.03
# tsnr                                                 -0.16      -0.01
# fd_mean                                               0.08       0.13
# ppi_c9_F-C_sub-neg_type-ppi_seed-VS_thr5_cope-09     -0.24      -0.13
# ppi_C10_FS-C_z8_sub-neg_cluster1_type-ppi_seed-...   -0.21      -0.02
# ppi_C10_FS-C_z8_sub-neg_cluster2_type-ppi_seed-...   -0.21      -0.02
# ppi_C13_rew-pun_F-C_z1_main-effect_type-ppi_see...  -0.33*      -0.17
# ppi_C13_rew-pun_F-C_z12_su-rs2-neg_cluster1_typ...   0.37*       0.04
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...   -0.01        0.1
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...   -0.03       0.03
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...   -0.22       0.03
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...   -0.25      -0.06
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...    0.19      -0.09
# Unnamed: 19                                            nan        nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...   -0.04      -0.08
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...    -0.0      -0.17
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13      -0.0      -0.01
# act_C14_rew_F-S_z2_sub_type-act_cope-14              -0.08      -0.17
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16      0.04      -0.14
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16      -0.0       0.12
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16      0.04      -0.06
# Unnamed: 27                                            nan        nan
# aTPJ_VS_ppi_cope_01                                   0.13      -0.12
# aTPJ_VS_ppi_cope_02                                  -0.07       0.01
# aTPJ_VS_ppi_cope_03                                   0.06      -0.14
# aTPJ_VS_ppi_cope_04                                   0.03       0.01
# aTPJ_VS_ppi_cope_05                                   0.14      -0.02
# aTPJ_VS_ppi_cope_06                                    0.2      -0.03
# pTPJ_VS_ppi_cope_01                                   0.01      -0.12
# pTPJ_VS_ppi_cope_02                                   0.03      -0.15
# pTPJ_VS_ppi_cope_03                                   0.08       0.12
# pTPJ_VS_ppi_cope_04                                   0.08       0.01
# pTPJ_VS_ppi_cope_05                                   0.06      -0.08
# pTPJ_VS_ppi_cope_06                                   0.21       0.04
# VS_seed_F_S                                            0.0       -0.2
# VS_seed_F_C                                            0.0      -0.11
# win_C                                                -0.05       0.07
# win_F                                                -0.09      -0.07
# win_S                                                -0.07       0.16
# Unnamed: 46                                            nan        nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1        -0.05      -0.09
# act_VS-seed_11-rew-pun_F-S                           -0.16      -0.29
# act_VS-seed_13-rew-pun_F-C                           -0.03      -0.24
# act_VS-seed_14-rew_F-S                                -0.0      -0.21
# act_VS-seed_16-rew_F-C                                -0.0      -0.11
# act_VS-seed_21-rew_F-SC                               0.02      -0.19
# act_VS-seed_23-rew-pun_F-SC                          -0.08     -0.31*
# ios_diff_computer                                    -0.24       0.13
# ios_diff_stranger                                    -0.06       0.16
# ios_diff_fu                                          -0.18      -0.04
# Win_F_C                                               0.19     0.44**
# Win_F_S                                               0.14      0.38*
# Diff_Friend                                           0.29    0.77***
# Diff_Stranger                                         0.07      0.36*
# Diff_Comp                                            -0.08       0.23
# Win_Lose_F_S                                           0.2      0.38*
# Win_Lose_F_C                                          0.3*     0.48**
# aTPJ_R_P_F_C                                          0.08       0.03
# aTPJ_R_P_F_S                                         -0.06       0.11
# pTPJ_R_F_S                                           -0.12      -0.03
# pTPJ_R_P_F_C                                         -0.02      -0.04
# pTPJ_R_P_F_S                                          -0.1      -0.13
#
#                                                    Win-Stranger  Win-Comp  \
# sub                                                        0.02     -0.06
# Win-Friend                                                0.37*      0.18
# Win-Stranger                                             1.0***     0.37*
# Win-Comp                                                  0.37*    1.0***
# Lose-Friend                                               -0.24      0.02
# Lose-Stranger                                            -0.33*     -0.01
# Lose-Comp                                                 -0.21      0.15
# ios_fu_score                                               0.23     -0.19
# ios_computer                                                0.2      0.09
# ios_f                                                     0.4**      0.08
# ios_p                                                     0.36*      0.12
# audit_standard_score                                      -0.09     -0.11
# Subject                                                    0.02     -0.06
# Ones                                                        nan       nan
# SU                                                        -0.01      0.08
# RS                                                        -0.02      -0.2
# RS_square                                                  0.02     -0.18
# SUxRS                                                      0.14      0.18
# SUxRS_sq                                                   0.11     -0.07
# tsnr                                                       0.07     -0.05
# fd_mean                                                    0.21      0.07
# ppi_c9_F-C_sub-neg_type-ppi_seed-VS_thr5_cope-09          -0.06     -0.05
# ppi_C10_FS-C_z8_sub-neg_cluster1_type-ppi_seed-...          0.0     -0.03
# ppi_C10_FS-C_z8_sub-neg_cluster2_type-ppi_seed-...          0.0     -0.03
# ppi_C13_rew-pun_F-C_z1_main-effect_type-ppi_see...       -0.38*     -0.23
# ppi_C13_rew-pun_F-C_z12_su-rs2-neg_cluster1_typ...         0.06      0.22
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...         0.12     -0.04
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...        -0.02      0.09
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...        -0.24     -0.18
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...        -0.24      -0.2
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...        -0.12      0.02
# Unnamed: 19                                                 nan       nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...        -0.16     -0.12
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...        -0.11      0.05
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13          -0.19      0.12
# act_C14_rew_F-S_z2_sub_type-act_cope-14                  -0.34*     -0.09
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16        -0.47**     -0.06
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16           0.09     0.31*
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16          -0.02      0.11
# Unnamed: 27                                                 nan       nan
# aTPJ_VS_ppi_cope_01                                       -0.27     -0.12
# aTPJ_VS_ppi_cope_02                                       -0.03     -0.01
# aTPJ_VS_ppi_cope_03                                        -0.0     -0.02
# aTPJ_VS_ppi_cope_04                                       -0.03     -0.09
# aTPJ_VS_ppi_cope_05                                       -0.05      0.15
# aTPJ_VS_ppi_cope_06                                       -0.14      0.13
# pTPJ_VS_ppi_cope_01                                       -0.26     -0.22
# pTPJ_VS_ppi_cope_02                                        0.12     -0.23
# pTPJ_VS_ppi_cope_03                                        0.09     -0.11
# pTPJ_VS_ppi_cope_04                                        0.06     -0.26
# pTPJ_VS_ppi_cope_05                                       -0.01      0.02
# pTPJ_VS_ppi_cope_06                                       -0.05     -0.16
# VS_seed_F_S                                               -0.06     -0.03
# VS_seed_F_C                                               -0.29     -0.25
# win_C                                                    0.42**      0.26
# win_F                                                      0.19     -0.02
# win_S                                                      0.23      0.02
# Unnamed: 46                                                 nan       nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1            -0.33*      0.09
# act_VS-seed_11-rew-pun_F-S                                -0.05      0.02
# act_VS-seed_13-rew-pun_F-C                                -0.24     -0.26
# act_VS-seed_14-rew_F-S                                    -0.06     -0.03
# act_VS-seed_16-rew_F-C                                    -0.28     -0.24
# act_VS-seed_21-rew_F-SC                                   -0.22     -0.21
# act_VS-seed_23-rew-pun_F-SC                                -0.2     -0.19
# ios_diff_computer                                          0.22      0.03
# ios_diff_stranger                                          0.19      0.22
# ios_diff_fu                                                0.02     -0.19
# Win_F_C                                                   -0.11   -0.8***
# Win_F_S                                                -0.72***     -0.23
# Diff_Friend                                               0.36*      0.08
# Diff_Stranger                                           0.87***      0.26
# Diff_Comp                                                0.46**   0.77***
# Win_Lose_F_S                                            -0.47**     -0.16
# Win_Lose_F_C                                              -0.05  -0.53***
# aTPJ_R_P_F_C                                              -0.14     -0.08
# aTPJ_R_P_F_S                                               0.04     -0.04
# pTPJ_R_F_S                                                 0.08     -0.06
# pTPJ_R_P_F_C                                              -0.24     -0.04
# pTPJ_R_P_F_S                                              -0.01      0.04
#
#                                                    Lose-Friend Lose-Stranger  \
# sub                                                      -0.26         -0.11
# Win-Friend                                              -0.36*         -0.19
# Win-Stranger                                             -0.24        -0.33*
# Win-Comp                                                  0.02         -0.01
# Lose-Friend                                             1.0***          0.28
# Lose-Stranger                                             0.28        1.0***
# Lose-Comp                                                0.35*       0.65***
# ios_fu_score                                             -0.27          0.03
# ios_computer                                             -0.33        -0.41*
# ios_f                                                      0.0         -0.02
# ios_p                                                    -0.21         -0.19
# audit_standard_score                                      0.26          0.02
# Subject                                                  -0.26         -0.11
# Ones                                                       nan           nan
# SU                                                        0.04         -0.17
# RS                                                       -0.09         -0.16
# RS_square                                                -0.13          0.28
# SUxRS                                                     0.03         0.34*
# SUxRS_sq                                                  0.11         -0.18
# tsnr                                                      0.02         0.32*
# fd_mean                                                   -0.1         -0.27
# ppi_c9_F-C_sub-neg_type-ppi_seed-VS_thr5_cope-09          0.15          0.27
# ppi_C10_FS-C_z8_sub-neg_cluster1_type-ppi_seed-...        0.13          0.26
# ppi_C10_FS-C_z8_sub-neg_cluster2_type-ppi_seed-...        0.13          0.26
# ppi_C13_rew-pun_F-C_z1_main-effect_type-ppi_see...        0.06           0.3
# ppi_C13_rew-pun_F-C_z12_su-rs2-neg_cluster1_typ...       -0.03         -0.18
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...       -0.13         -0.12
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...         0.0          0.01
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...        0.13          0.24
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...        0.12          0.21
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...       -0.18         -0.17
# Unnamed: 19                                                nan           nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...        0.08         -0.16
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...         0.1         -0.22
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13          0.07          -0.0
# act_C14_rew_F-S_z2_sub_type-act_cope-14                  0.33*          0.27
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16          0.3*          0.13
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16           0.1          0.13
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16         -0.02         -0.14
# Unnamed: 27                                                nan           nan
# aTPJ_VS_ppi_cope_01                                      -0.08          -0.2
# aTPJ_VS_ppi_cope_02                                      -0.25         -0.05
# aTPJ_VS_ppi_cope_03                                       0.01          0.08
# aTPJ_VS_ppi_cope_04                                      -0.21         -0.15
# aTPJ_VS_ppi_cope_05                                      -0.23          -0.0
# aTPJ_VS_ppi_cope_06                                      -0.11          0.12
# pTPJ_VS_ppi_cope_01                                       0.02          -0.1
# pTPJ_VS_ppi_cope_02                                      -0.18         -0.28
# pTPJ_VS_ppi_cope_03                                      -0.16          0.06
# pTPJ_VS_ppi_cope_04                                      -0.24         -0.29
# pTPJ_VS_ppi_cope_05                                       0.04          0.23
# pTPJ_VS_ppi_cope_06                                      -0.24          0.14
# VS_seed_F_S                                               0.16           0.1
# VS_seed_F_C                                              -0.07         -0.18
# win_C                                                     0.17          0.17
# win_F                                                     0.17         -0.03
# win_S                                                    -0.03         -0.14
# Unnamed: 46                                                nan           nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1             0.27          0.12
# act_VS-seed_11-rew-pun_F-S                                0.28          0.06
# act_VS-seed_13-rew-pun_F-C                                0.11         -0.24
# act_VS-seed_14-rew_F-S                                    0.16           0.1
# act_VS-seed_16-rew_F-C                                   -0.06         -0.19
# act_VS-seed_21-rew_F-SC                                    0.0         -0.09
# act_VS-seed_23-rew-pun_F-SC                               0.18         -0.14
# ios_diff_computer                                         0.03          0.16
# ios_diff_stranger                                        -0.02         -0.15
# ios_diff_fu                                               0.05          0.31
# Win_F_C                                                  -0.24         -0.11
# Win_F_S                                                  -0.03          0.19
# Diff_Friend                                           -0.87***         -0.29
# Diff_Stranger                                           -0.31*      -0.76***
# Diff_Comp                                                 -0.2       -0.43**
# Win_Lose_F_S                                          -0.51***        0.43**
# Win_Lose_F_C                                          -0.59***          0.09
# aTPJ_R_P_F_C                                             -0.03          -0.2
# aTPJ_R_P_F_S                                             -0.18         -0.21
# pTPJ_R_F_S                                                0.02        -0.34*
# pTPJ_R_P_F_C                                              0.09         -0.05
# pTPJ_R_P_F_S                                              0.13         -0.15
#
#                                                    Lose-Comp ios_fu_score  \
# sub                                                     0.03          0.3
# Win-Friend                                              -0.1         0.12
# Win-Stranger                                           -0.21         0.23
# Win-Comp                                                0.15        -0.19
# Lose-Friend                                            0.35*        -0.27
# Lose-Stranger                                        0.65***         0.03
# Lose-Comp                                             1.0***         0.09
# ios_fu_score                                            0.09       1.0***
# ios_computer                                           -0.36         0.11
# ios_f                                                  -0.13         0.04
# ios_p                                                  -0.18         0.02
# audit_standard_score                                    0.03         0.13
# Subject                                                 0.03          0.3
# Ones                                                     nan          nan
# SU                                                     -0.11          0.2
# RS                                                      -0.1         0.24
# RS_square                                               0.13         0.03
# SUxRS                                                   0.11         0.16
# SUxRS_sq                                               -0.05          0.3
# tsnr                                                    0.23        -0.09
# fd_mean                                                 -0.2         0.18
# ppi_c9_F-C_sub-neg_type-ppi_seed-VS_thr5_cope-09        0.28         0.05
# ppi_C10_FS-C_z8_sub-neg_cluster1_type-ppi_seed-...      0.27          0.0
# ppi_C10_FS-C_z8_sub-neg_cluster2_type-ppi_seed-...      0.27          0.0
# ppi_C13_rew-pun_F-C_z1_main-effect_type-ppi_see...     -0.19         0.01
# ppi_C13_rew-pun_F-C_z12_su-rs2-neg_cluster1_typ...     -0.15         0.03
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...     -0.23         0.03
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...     -0.15         0.02
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...     -0.04         0.07
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...     -0.09        -0.13
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...     -0.11        -0.17
# Unnamed: 19                                              nan          nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...     -0.18       -0.38*
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...      -0.1      -0.52**
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13       -0.13        -0.29
# act_C14_rew_F-S_z2_sub_type-act_cope-14                 0.25        -0.31
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16        0.17       -0.38*
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16        0.03        -0.35
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16       -0.21        -0.29
# Unnamed: 27                                              nan          nan
# aTPJ_VS_ppi_cope_01                                    -0.12         0.04
# aTPJ_VS_ppi_cope_02                                    -0.14        -0.04
# aTPJ_VS_ppi_cope_03                                     0.19        -0.09
# aTPJ_VS_ppi_cope_04                                     -0.1        -0.17
# aTPJ_VS_ppi_cope_05                                     0.01         0.07
# aTPJ_VS_ppi_cope_06                                     0.29         0.05
# pTPJ_VS_ppi_cope_01                                    -0.01         0.25
# pTPJ_VS_ppi_cope_02                                    -0.24         0.03
# pTPJ_VS_ppi_cope_03                                    -0.01        -0.29
# pTPJ_VS_ppi_cope_04                                    -0.29         0.15
# pTPJ_VS_ppi_cope_05                                     0.06         0.03
# pTPJ_VS_ppi_cope_06                                     0.15         0.21
# VS_seed_F_S                                             0.14        -0.26
# VS_seed_F_C                                            -0.12        -0.07
# win_C                                                   0.21         0.19
# win_F                                                   0.12          0.1
# win_S                                                  -0.05         0.4*
# Unnamed: 46                                              nan          nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1           0.14        -0.13
# act_VS-seed_11-rew-pun_F-S                              0.16       -0.46*
# act_VS-seed_13-rew-pun_F-C                             -0.04        -0.28
# act_VS-seed_14-rew_F-S                                  0.13        -0.24
# act_VS-seed_16-rew_F-C                                 -0.12        -0.08
# act_VS-seed_21-rew_F-SC                                -0.05        -0.14
# act_VS-seed_23-rew-pun_F-SC                             0.04       -0.41*
# ios_diff_computer                                       0.13        -0.07
# ios_diff_stranger                                      -0.19     -0.69***
# ios_diff_fu                                             0.32      0.65***
# Win_F_C                                                 -0.2         0.24
# Win_F_S                                                 0.13        -0.15
# Diff_Friend                                            -0.29         0.27
# Diff_Stranger                                       -0.49***         0.14
# Diff_Comp                                           -0.51***        -0.22
# Win_Lose_F_S                                            0.19         0.09
# Win_Lose_F_C                                            0.15        0.39*
# aTPJ_R_P_F_C                                           -0.16         -0.0
# aTPJ_R_P_F_S                                          -0.35*        -0.04
# pTPJ_R_F_S                                            -0.35*        -0.08
# pTPJ_R_P_F_C                                            0.01         0.31
# pTPJ_R_P_F_S                                            -0.2         0.12
#
#                                                    ios_computer    ios_f  \
# sub                                                      0.52**    -0.11
# Win-Friend                                                 0.17     0.13
# Win-Stranger                                                0.2    0.4**
# Win-Comp                                                   0.09     0.08
# Lose-Friend                                               -0.33      0.0
# Lose-Stranger                                            -0.41*    -0.02
# Lose-Comp                                                 -0.36    -0.13
# ios_fu_score                                               0.11     0.04
# ios_computer                                             1.0***    -0.07
# ios_f                                                     -0.07   1.0***
# ios_p                                                      0.17  0.48***
# audit_standard_score                                        0.0     0.18
# Subject                                                  0.52**    -0.11
# Ones                                                        nan      nan
# SU                                                         0.13      0.0
# RS                                                         0.16    -0.02
# RS_square                                                 -0.05     0.07
# SUxRS                                                     -0.25     0.18
# SUxRS_sq                                                   0.02     0.09
# tsnr                                                      -0.18    -0.13
# fd_mean                                                    0.25     0.23
# ppi_c9_F-C_sub-neg_type-ppi_seed-VS_thr5_cope-09          -0.03     0.21
# ppi_C10_FS-C_z8_sub-neg_cluster1_type-ppi_seed-...        -0.17     0.22
# ppi_C10_FS-C_z8_sub-neg_cluster2_type-ppi_seed-...        -0.17     0.22
# ppi_C13_rew-pun_F-C_z1_main-effect_type-ppi_see...         -0.3     0.05
# ppi_C13_rew-pun_F-C_z12_su-rs2-neg_cluster1_typ...         0.37    -0.28
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...        -0.09     0.21
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...        -0.22    -0.16
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...        -0.33     0.05
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...       -0.38*     0.15
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...         -0.0    -0.11
# Unnamed: 19                                                 nan      nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...        -0.13     -0.1
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...        -0.04    -0.05
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13          -0.15   -0.33*
# act_C14_rew_F-S_z2_sub_type-act_cope-14                   -0.37     0.01
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16           0.03    -0.25
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16          -0.13    -0.09
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16          -0.06    -0.15
# Unnamed: 27                                                 nan      nan
# aTPJ_VS_ppi_cope_01                                        0.35    -0.14
# aTPJ_VS_ppi_cope_02                                        0.02     0.09
# aTPJ_VS_ppi_cope_03                                       -0.19    -0.09
# aTPJ_VS_ppi_cope_04                                       -0.25    -0.07
# aTPJ_VS_ppi_cope_05                                        -0.0    -0.19
# aTPJ_VS_ppi_cope_06                                       -0.21    -0.25
# pTPJ_VS_ppi_cope_01                                        -0.0   -0.37*
# pTPJ_VS_ppi_cope_02                                        -0.2     0.06
# pTPJ_VS_ppi_cope_03                                      -0.38*    -0.06
# pTPJ_VS_ppi_cope_04                                       -0.12    -0.18
# pTPJ_VS_ppi_cope_05                                       -0.13    -0.27
# pTPJ_VS_ppi_cope_06                                      -0.47*   -0.29*
# VS_seed_F_S                                               -0.27    -0.15
# VS_seed_F_C                                              -0.41*   -0.31*
# win_C                                                      0.34    0.33*
# win_F                                                     -0.22     0.01
# win_S                                                      0.09     0.17
# Unnamed: 46                                                 nan      nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1             -0.14     0.16
# act_VS-seed_11-rew-pun_F-S                                -0.12    -0.13
# act_VS-seed_13-rew-pun_F-C                                -0.27    -0.27
# act_VS-seed_14-rew_F-S                                    -0.26    -0.15
# act_VS-seed_16-rew_F-C                                    -0.4*   -0.31*
# act_VS-seed_21-rew_F-SC                                   -0.37    -0.3*
# act_VS-seed_23-rew-pun_F-SC                               -0.24    -0.25
# ios_diff_computer                                      -0.64***    0.44*
# ios_diff_stranger                                          0.05     0.33
# ios_diff_fu                                            -0.68***     0.08
# Win_F_C                                                    -0.0     0.01
# Win_F_S                                                   -0.09     -0.3
# Diff_Friend                                                0.34     0.07
# Diff_Stranger                                              0.35     0.29
# Diff_Comp                                                  0.31     0.16
# Win_Lose_F_S                                              -0.04     -0.2
# Win_Lose_F_C                                                0.0    -0.07
# aTPJ_R_P_F_C                                               0.14     -0.1
# aTPJ_R_P_F_S                                                0.1     0.07
# pTPJ_R_F_S                                                0.39*     0.11
# pTPJ_R_P_F_C                                               0.25    -0.29
# pTPJ_R_P_F_S                                               0.4*    -0.02
#
#                                                       ios_p  \
# sub                                                    0.23
# Win-Friend                                             0.26
# Win-Stranger                                          0.36*
# Win-Comp                                               0.12
# Lose-Friend                                           -0.21
# Lose-Stranger                                         -0.19
# Lose-Comp                                             -0.18
# ios_fu_score                                           0.02
# ios_computer                                           0.17
# ios_f                                               0.48***
# ios_p                                                1.0***
# audit_standard_score                                   0.06
# Subject                                                0.23
# Ones                                                    nan
# SU                                                     0.12
# RS                                                    -0.08
# RS_square                                              0.07
# SUxRS                                                  0.03
# SUxRS_sq                                              -0.22
# tsnr                                                  -0.04
# fd_mean                                               -0.01
# ppi_c9_F-C_sub-neg_type-ppi_seed-VS_thr5_cope-09      -0.08
# ppi_C10_FS-C_z8_sub-neg_cluster1_type-ppi_seed-...    -0.06
# ppi_C10_FS-C_z8_sub-neg_cluster2_type-ppi_seed-...    -0.06
# ppi_C13_rew-pun_F-C_z1_main-effect_type-ppi_see...    -0.02
# ppi_C13_rew-pun_F-C_z12_su-rs2-neg_cluster1_typ...      0.1
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...     0.14
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...    -0.13
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...    -0.04
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...     0.03
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...     0.26
# Unnamed: 19                                             nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...    -0.19
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...    -0.02
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13      -0.08
# act_C14_rew_F-S_z2_sub_type-act_cope-14                0.14
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16        0.0
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16        0.0
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16       0.07
# Unnamed: 27                                             nan
# aTPJ_VS_ppi_cope_01                                   -0.18
# aTPJ_VS_ppi_cope_02                                   -0.25
# aTPJ_VS_ppi_cope_03                                   -0.11
# aTPJ_VS_ppi_cope_04                                    0.07
# aTPJ_VS_ppi_cope_05                                   -0.11
# aTPJ_VS_ppi_cope_06                                   -0.08
# pTPJ_VS_ppi_cope_01                                  -0.34*
# pTPJ_VS_ppi_cope_02                                   -0.06
# pTPJ_VS_ppi_cope_03                                     0.0
# pTPJ_VS_ppi_cope_04                                    0.05
# pTPJ_VS_ppi_cope_05                                   -0.26
# pTPJ_VS_ppi_cope_06                                   -0.17
# VS_seed_F_S                                            0.03
# VS_seed_F_C                                            -0.1
# win_C                                                  0.09
# win_F                                                 -0.02
# win_S                                                 -0.05
# Unnamed: 46                                             nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1          0.08
# act_VS-seed_11-rew-pun_F-S                            -0.21
# act_VS-seed_13-rew-pun_F-C                            -0.21
# act_VS-seed_14-rew_F-S                                 0.02
# act_VS-seed_16-rew_F-C                                 -0.1
# act_VS-seed_21-rew_F-SC                               -0.06
# act_VS-seed_23-rew-pun_F-SC                           -0.25
# ios_diff_computer                                   0.64***
# ios_diff_stranger                                   0.71***
# ios_diff_fu                                           -0.12
# Win_F_C                                                0.05
# Win_F_S                                               -0.17
# Diff_Friend                                            0.28
# Diff_Stranger                                         0.35*
# Diff_Comp                                              0.22
# Win_Lose_F_S                                          -0.07
# Win_Lose_F_C                                           0.06
# aTPJ_R_P_F_C                                           0.14
# aTPJ_R_P_F_S                                           0.11
# pTPJ_R_F_S                                             0.19
# pTPJ_R_P_F_C                                          -0.13
# pTPJ_R_P_F_S                                           -0.0
#
#                                                    audit_standard_score  \
# sub                                                               -0.22
# Win-Friend                                                        -0.09
# Win-Stranger                                                      -0.09
# Win-Comp                                                          -0.11
# Lose-Friend                                                        0.26
# Lose-Stranger                                                      0.02
# Lose-Comp                                                          0.03
# ios_fu_score                                                       0.13
# ios_computer                                                        0.0
# ios_f                                                              0.18
# ios_p                                                              0.06
# audit_standard_score                                             1.0***
# Subject                                                           -0.22
# Ones                                                                nan
# SU                                                               0.8***
# RS                                                                 0.03
# RS_square                                                         -0.16
# SUxRS                                                             -0.24
# SUxRS_sq                                                        0.72***
# tsnr                                                              -0.21
# fd_mean                                                            0.16
# ppi_c9_F-C_sub-neg_type-ppi_seed-VS_thr5_cope-09                  -0.23
# ppi_C10_FS-C_z8_sub-neg_cluster1_type-ppi_seed-...                -0.26
# ppi_C10_FS-C_z8_sub-neg_cluster2_type-ppi_seed-...                -0.26
# ppi_C13_rew-pun_F-C_z1_main-effect_type-ppi_see...                 0.15
# ppi_C13_rew-pun_F-C_z12_su-rs2-neg_cluster1_typ...                -0.13
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...                 0.12
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...                 0.06
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...                -0.01
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...                 0.15
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...                 0.06
# Unnamed: 19                                                         nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...                -0.08
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...                 0.01
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13                  -0.03
# act_C14_rew_F-S_z2_sub_type-act_cope-14                         0.53***
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16                0.48***
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16                  0.34*
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16                 0.41**
# Unnamed: 27                                                         nan
# aTPJ_VS_ppi_cope_01                                                0.14
# aTPJ_VS_ppi_cope_02                                               -0.14
# aTPJ_VS_ppi_cope_03                                               -0.13
# aTPJ_VS_ppi_cope_04                                               -0.08
# aTPJ_VS_ppi_cope_05                                               -0.02
# aTPJ_VS_ppi_cope_06                                               -0.17
# pTPJ_VS_ppi_cope_01                                               -0.15
# pTPJ_VS_ppi_cope_02                                               -0.17
# pTPJ_VS_ppi_cope_03                                                -0.2
# pTPJ_VS_ppi_cope_04                                               -0.19
# pTPJ_VS_ppi_cope_05                                               -0.02
# pTPJ_VS_ppi_cope_06                                               -0.29
# VS_seed_F_S                                                        0.11
# VS_seed_F_C                                                       -0.19
# win_C                                                              0.13
# win_F                                                             -0.12
# win_S                                                             -0.22
# Unnamed: 46                                                         nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1                      0.26
# act_VS-seed_11-rew-pun_F-S                                        -0.06
# act_VS-seed_13-rew-pun_F-C                                        -0.15
# act_VS-seed_14-rew_F-S                                             0.11
# act_VS-seed_16-rew_F-C                                            -0.19
# act_VS-seed_21-rew_F-SC                                           -0.09
# act_VS-seed_23-rew-pun_F-SC                                       -0.14
# ios_diff_computer                                                   0.0
# ios_diff_stranger                                                 -0.09
# ios_diff_fu                                                         0.1
# Win_F_C                                                            0.04
# Win_F_S                                                            0.02
# Diff_Friend                                                       -0.23
# Diff_Stranger                                                     -0.07
# Diff_Comp                                                         -0.12
# Win_Lose_F_S                                                      -0.14
# Win_Lose_F_C                                                       -0.1
# aTPJ_R_P_F_C                                                       0.18
# aTPJ_R_P_F_S                                                       0.14
# pTPJ_R_F_S                                                          0.1
# pTPJ_R_P_F_C                                                       0.04
# pTPJ_R_P_F_S                                                       0.18
#
#                                                    Subject    Ones       SU  \
# sub                                                 1.0***     nan     0.03
# Win-Friend                                            0.21     nan     0.02
# Win-Stranger                                          0.02     nan    -0.01
# Win-Comp                                             -0.06     nan     0.08
# Lose-Friend                                          -0.26     nan     0.04
# Lose-Stranger                                        -0.11     nan    -0.17
# Lose-Comp                                             0.03     nan    -0.11
# ios_fu_score                                           0.3     nan      0.2
# ios_computer                                        0.52**     nan     0.13
# ios_f                                                -0.11     nan      0.0
# ios_p                                                 0.23     nan     0.12
# audit_standard_score                                 -0.22     nan   0.8***
# Subject                                             1.0***     nan     0.03
# Ones                                                   nan  nan***      nan
# SU                                                    0.03     nan   1.0***
# RS                                                   -0.01     nan     0.07
# RS_square                                             0.02     nan    -0.24
# SUxRS                                                 0.02     nan    -0.09
# SUxRS_sq                                             -0.23     nan  0.57***
# tsnr                                                 -0.16     nan   -0.36*
# fd_mean                                               0.08     nan     0.18
# ppi_c9_F-C_sub-neg_type-ppi_seed-VS_thr5_cope-09     -0.24     nan  -0.6***
# ppi_C10_FS-C_z8_sub-neg_cluster1_type-ppi_seed-...   -0.21     nan  -0.6***
# ppi_C10_FS-C_z8_sub-neg_cluster2_type-ppi_seed-...   -0.21     nan  -0.6***
# ppi_C13_rew-pun_F-C_z1_main-effect_type-ppi_see...  -0.33*     nan      0.1
# ppi_C13_rew-pun_F-C_z12_su-rs2-neg_cluster1_typ...   0.37*     nan     0.26
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...   -0.01     nan    0.36*
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...   -0.03     nan     0.24
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...   -0.22     nan    -0.02
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...   -0.25     nan     0.11
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...    0.19     nan    0.33*
# Unnamed: 19                                            nan     nan      nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...   -0.04     nan    -0.21
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...    -0.0     nan    -0.05
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13      -0.0     nan     0.21
# act_C14_rew_F-S_z2_sub_type-act_cope-14              -0.08     nan  0.57***
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16      0.04     nan  0.49***
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16      -0.0     nan   0.6***
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16      0.04     nan  0.65***
# Unnamed: 27                                            nan     nan      nan
# aTPJ_VS_ppi_cope_01                                   0.13     nan     0.18
# aTPJ_VS_ppi_cope_02                                  -0.07     nan    -0.15
# aTPJ_VS_ppi_cope_03                                   0.06     nan    -0.18
# aTPJ_VS_ppi_cope_04                                   0.03     nan     0.07
# aTPJ_VS_ppi_cope_05                                   0.14     nan     0.13
# aTPJ_VS_ppi_cope_06                                    0.2     nan    -0.19
# pTPJ_VS_ppi_cope_01                                   0.01     nan    -0.17
# pTPJ_VS_ppi_cope_02                                   0.03     nan    -0.07
# pTPJ_VS_ppi_cope_03                                   0.08     nan    -0.19
# pTPJ_VS_ppi_cope_04                                   0.08     nan     -0.0
# pTPJ_VS_ppi_cope_05                                   0.06     nan     0.05
# pTPJ_VS_ppi_cope_06                                   0.21     nan    -0.25
# VS_seed_F_S                                            0.0     nan     0.04
# VS_seed_F_C                                            0.0     nan    -0.16
# win_C                                                -0.05     nan     0.06
# win_F                                                -0.09     nan    -0.18
# win_S                                                -0.07     nan    -0.19
# Unnamed: 46                                            nan     nan      nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1        -0.05     nan     0.12
# act_VS-seed_11-rew-pun_F-S                           -0.16     nan    -0.24
# act_VS-seed_13-rew-pun_F-C                           -0.03     nan    -0.18
# act_VS-seed_14-rew_F-S                                -0.0     nan     0.03
# act_VS-seed_16-rew_F-C                                -0.0     nan    -0.16
# act_VS-seed_21-rew_F-SC                               0.02     nan     -0.1
# act_VS-seed_23-rew-pun_F-SC                          -0.08     nan    -0.24
# ios_diff_computer                                    -0.24     nan    -0.14
# ios_diff_stranger                                    -0.06     nan    -0.18
# ios_diff_fu                                          -0.18     nan     0.05
# Win_F_C                                               0.19     nan    -0.07
# ...
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...         0.17        0.35*
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...        -0.19        -0.16
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...         0.26        0.35*
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...         0.25       0.42**
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...      0.59***      0.49***
# Unnamed: 19                                                 nan          nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...        -0.12        -0.14
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...        -0.06         -0.1
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13          -0.05          0.2
# act_C14_rew_F-S_z2_sub_type-act_cope-14                    0.24         0.18
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16           0.06        -0.02
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16           0.19        0.4**
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16           0.19        0.33*
# Unnamed: 27                                                 nan          nan
# aTPJ_VS_ppi_cope_01                                     0.48***         0.14
# aTPJ_VS_ppi_cope_02                                      -0.37*        -0.13
# aTPJ_VS_ppi_cope_03                                     -0.5***     -0.69***
# aTPJ_VS_ppi_cope_04                                      0.46**         0.28
# aTPJ_VS_ppi_cope_05                                       -0.05         0.17
# aTPJ_VS_ppi_cope_06                                       -0.21      -0.43**
# pTPJ_VS_ppi_cope_01                                       -0.01        -0.19
# pTPJ_VS_ppi_cope_02                                       -0.27        -0.15
# pTPJ_VS_ppi_cope_03                                    -0.49***     -0.53***
# pTPJ_VS_ppi_cope_04                                         0.2        0.31*
# pTPJ_VS_ppi_cope_05                                       -0.28         0.01
# pTPJ_VS_ppi_cope_06                                      -0.37*       -0.38*
# VS_seed_F_S                                                -0.1        -0.18
# VS_seed_F_C                                               -0.17        -0.24
# win_C                                                      0.11         0.18
# win_F                                                     -0.11        -0.11
# win_S                                                      0.02         0.11
# Unnamed: 46                                                 nan          nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1             -0.07        -0.19
# act_VS-seed_11-rew-pun_F-S                                 0.04        -0.04
# act_VS-seed_13-rew-pun_F-C                                -0.17        -0.24
# act_VS-seed_14-rew_F-S                                     -0.1        -0.18
# act_VS-seed_16-rew_F-C                                    -0.17        -0.24
# act_VS-seed_21-rew_F-SC                                   -0.16        -0.24
# act_VS-seed_23-rew-pun_F-SC                                -0.1        -0.18
# ios_diff_computer                                         -0.14        -0.03
# ios_diff_stranger                                         -0.03         0.07
# ios_diff_fu                                               -0.11         -0.1
# Win_F_C                                                    0.09          0.1
# Win_F_S                                                    0.15         0.05
# Diff_Friend                                                0.04         0.18
# Diff_Stranger                                              0.01         0.14
# Diff_Comp                                                  0.03         0.19
# Win_Lose_F_S                                               0.02         0.04
# Win_Lose_F_C                                               0.01         0.01
# aTPJ_R_P_F_C                                             1.0***      0.73***
# aTPJ_R_P_F_S                                            0.73***       1.0***
# pTPJ_R_F_S                                              0.48***      0.58***
# pTPJ_R_P_F_C                                            0.54***       0.44**
# pTPJ_R_P_F_S                                            0.49***      0.72***
#
#                                                    pTPJ_R_F_S pTPJ_R_P_F_C  \
# sub                                                     -0.12        -0.02
# Win-Friend                                              -0.03        -0.04
# Win-Stranger                                             0.08        -0.24
# Win-Comp                                                -0.06        -0.04
# Lose-Friend                                              0.02         0.09
# Lose-Stranger                                          -0.34*        -0.05
# Lose-Comp                                              -0.35*         0.01
# ios_fu_score                                            -0.08         0.31
# ios_computer                                            0.39*         0.25
# ios_f                                                    0.11        -0.29
# ios_p                                                    0.19        -0.13
# audit_standard_score                                      0.1         0.04
# Subject                                                 -0.12        -0.02
# Ones                                                      nan          nan
# SU                                                       0.21         0.06
# RS                                                        0.2         0.05
# RS_square                                               -0.05         0.07
# SUxRS                                                   -0.22        -0.14
# SUxRS_sq                                                -0.04        -0.05
# tsnr                                                    -0.06         0.03
# fd_mean                                                  0.09        -0.08
# ppi_c9_F-C_sub-neg_type-ppi_seed-VS_thr5_cope-09         -0.2         0.03
# ppi_C10_FS-C_z8_sub-neg_cluster1_type-ppi_seed-...      -0.29        -0.11
# ppi_C10_FS-C_z8_sub-neg_cluster2_type-ppi_seed-...      -0.29        -0.11
# ppi_C13_rew-pun_F-C_z1_main-effect_type-ppi_see...       0.27         0.14
# ppi_C13_rew-pun_F-C_z12_su-rs2-neg_cluster1_typ...       0.23          0.1
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...       0.3*        -0.04
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...      -0.26        -0.19
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...     0.39**         0.24
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...    0.49***         0.15
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...      0.32*         0.23
# Unnamed: 19                                               nan          nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...     -0.33*        -0.08
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...      -0.23        -0.07
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13         0.06        -0.05
# act_C14_rew_F-S_z2_sub_type-act_cope-14                  0.01         -0.0
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16        -0.04          0.1
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16         0.09         0.09
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16         0.08        -0.07
# Unnamed: 27                                               nan          nan
# aTPJ_VS_ppi_cope_01                                      0.14       0.43**
# aTPJ_VS_ppi_cope_02                                      -0.2        -0.16
# aTPJ_VS_ppi_cope_03                                    -0.34*       -0.34*
# aTPJ_VS_ppi_cope_04                                      0.18         0.02
# aTPJ_VS_ppi_cope_05                                     -0.14         0.18
# aTPJ_VS_ppi_cope_06                                  -0.52***        -0.15
# pTPJ_VS_ppi_cope_01                                     -0.16       0.46**
# pTPJ_VS_ppi_cope_02                                     -0.06       -0.4**
# pTPJ_VS_ppi_cope_03                                     -0.29     -0.68***
# pTPJ_VS_ppi_cope_04                                   0.55***         0.24
# pTPJ_VS_ppi_cope_05                                     -0.24        -0.18
# pTPJ_VS_ppi_cope_06                                  -0.64***        -0.22
# VS_seed_F_S                                             -0.23        -0.05
# VS_seed_F_C                                            -0.32*         0.02
# win_C                                                    0.28        -0.11
# win_F                                                   -0.09        -0.15
# win_S                                                    0.18        -0.07
# Unnamed: 46                                               nan          nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1           -0.13        -0.04
# act_VS-seed_11-rew-pun_F-S                              -0.19         0.16
# act_VS-seed_13-rew-pun_F-C                             -0.35*         0.06
# act_VS-seed_14-rew_F-S                                  -0.24        -0.04
# act_VS-seed_16-rew_F-C                                 -0.32*         0.02
# act_VS-seed_21-rew_F-SC                                -0.34*        -0.01
# act_VS-seed_23-rew-pun_F-SC                            -0.34*         0.12
# ios_diff_computer                                       -0.26        -0.24
# ios_diff_stranger                                         0.1        -0.26
# ios_diff_fu                                             -0.35         0.04
# Win_F_C                                                  0.04         0.01
# Win_F_S                                                  -0.1          0.2
# Diff_Friend                                             -0.03        -0.09
# Diff_Stranger                                            0.24        -0.14
# Diff_Comp                                                0.18        -0.04
# Win_Lose_F_S                                            -0.24         0.05
# Win_Lose_F_C                                            -0.17        -0.04
# aTPJ_R_P_F_C                                          0.48***      0.54***
# aTPJ_R_P_F_S                                          0.58***       0.44**
# pTPJ_R_F_S                                             1.0***       0.39**
# pTPJ_R_P_F_C                                           0.39**       1.0***
# pTPJ_R_P_F_S                                          0.74***      0.59***
#
#                                                    pTPJ_R_P_F_S
# sub                                                        -0.1
# Win-Friend                                                -0.13
# Win-Stranger                                              -0.01
# Win-Comp                                                   0.04
# Lose-Friend                                                0.13
# Lose-Stranger                                             -0.15
# Lose-Comp                                                  -0.2
# ios_fu_score                                               0.12
# ios_computer                                               0.4*
# ios_f                                                     -0.02
# ios_p                                                      -0.0
# audit_standard_score                                       0.18
# Subject                                                    -0.1
# Ones                                                        nan
# SU                                                         0.29
# RS                                                         0.01
# RS_square                                                 -0.14
# SUxRS                                                     -0.07
# SUxRS_sq                                                   0.02
# tsnr                                                       -0.1
# fd_mean                                                    0.16
# ppi_c9_F-C_sub-neg_type-ppi_seed-VS_thr5_cope-09          -0.18
# ppi_C10_FS-C_z8_sub-neg_cluster1_type-ppi_seed-...        -0.27
# ppi_C10_FS-C_z8_sub-neg_cluster2_type-ppi_seed-...        -0.27
# ppi_C13_rew-pun_F-C_z1_main-effect_type-ppi_see...         0.17
# ppi_C13_rew-pun_F-C_z12_su-rs2-neg_cluster1_typ...         0.17
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...          0.1
# ppi_C16_rew_F-C_z1_main-effect_cluster1_type-pp...       -0.32*
# ppi_C16_rew_F-C_z1_main-effect_cluster2_type-pp...        0.36*
# ppi_C21_rew_F-SC_z1_main-effect_type-ppi_seed-V...       0.44**
# ppi_C23_rew-pun_F-SC_z12_su-rs2-neg_cluster3_ty...        0.37*
# Unnamed: 19                                                 nan
# act_C13_rew-pun_F-C_z9_rs-neg_cluster1_type-act...        -0.17
# act_C13_rew-pun_F-C_z9_rs-neg_cluster2_type-act...        -0.06
# act_C13_rew-pun_F-C_z10_rs2-neg_type-act_cope-13           0.12
# act_C14_rew_F-S_z2_sub_type-act_cope-14                    0.15
# act_C16_rew_F-C_z2_sub_cluster1_type-act_cope-16           0.12
# act_C16_rew_F-C_z2_sub_cluster2_type-act_cope-16           0.25
# act_C16_rew_F-C_z2_sub_cluster3_type-act_cope-16           0.16
# Unnamed: 27                                                 nan
# aTPJ_VS_ppi_cope_01                                        0.15
# aTPJ_VS_ppi_cope_02                                       -0.12
# aTPJ_VS_ppi_cope_03                                    -0.58***
# aTPJ_VS_ppi_cope_04                                       -0.02
# aTPJ_VS_ppi_cope_05                                        0.13
# aTPJ_VS_ppi_cope_06                                     -0.43**
# pTPJ_VS_ppi_cope_01                                       -0.11
# pTPJ_VS_ppi_cope_02                                       -0.16
# pTPJ_VS_ppi_cope_03                                    -0.69***
# pTPJ_VS_ppi_cope_04                                       0.34*
# pTPJ_VS_ppi_cope_05                                        0.17
# pTPJ_VS_ppi_cope_06                                    -0.53***
# VS_seed_F_S                                               -0.18
# VS_seed_F_C                                               -0.26
# win_C                                                      0.22
# win_F                                                     -0.08
# win_S                                                      0.14
# Unnamed: 46                                                 nan
# act_c14_VS-wholebrain_rew-F-S_zstat1_cluster1              0.02
# act_VS-seed_11-rew-pun_F-S                                -0.06
# act_VS-seed_13-rew-pun_F-C                                -0.18
# act_VS-seed_14-rew_F-S                                    -0.18
# act_VS-seed_16-rew_F-C                                    -0.26
# act_VS-seed_21-rew_F-SC                                   -0.27
# act_VS-seed_23-rew-pun_F-SC                               -0.16
# ios_diff_computer                                         -0.31
# ios_diff_stranger                                         -0.09
# ios_diff_fu                                               -0.22
# Win_F_C                                                   -0.11
# Win_F_S                                                   -0.09
# Diff_Friend                                               -0.16
# Diff_Stranger                                              0.08
# Diff_Comp                                                  0.16
# Win_Lose_F_S                                              -0.22
# Win_Lose_F_C                                              -0.27
# aTPJ_R_P_F_C                                            0.49***
# aTPJ_R_P_F_S                                            0.72***
# pTPJ_R_F_S                                              0.74***
# pTPJ_R_P_F_C                                            0.59***
# pTPJ_R_P_F_S                                             1.0***

# %% [markdown]
# # Participant demographics for AUDIT and DUDIT

# %%
#All audit and dudit responses can be found in ISTART-All-Combined spreadsheet (found in derivatives) or phenotype .tsv files. Keys to interpreting numeric responses as drug types can be found in the phenotype .json files.
drug_type_list = df['dudit_drugtype'].tolist() #creates list of all dudit responses regarding drug type
audit_score_list = df['audit_standard_score'].tolist() #creates list of all audit scores, used to determine whether participants reached clinical threshold
print(drug_type_list, '\n\n', audit_score_list, '\n\n', df['dudit_drugtype'].unique()) #prints out above, as well as discrete drug usage types in the sample
len(audit_score_list) #number of participants who completed audit (and had scan data for shared reward task as well)
# Out:
# [0, nan, 0, 1, nan, nan, nan, nan, nan, nan, nan, nan, nan, 1, nan, 1, nan, nan, nan, '1,5', nan, nan, nan, 1, 1, nan, nan, 1, nan, 1, nan, 1, nan, nan, nan, 1, '1,5', 1, nan, nan, 1, nan, nan, '1,2', nan]
#
#  [6.666666667, 1.0, 1.0, 14.0, 0.0, 0.0, 2.222222222, 13.0, 1.0, 5.0, 3.0, 10.0, 3.0, 7.0, 0.0, 3.0, 2.0, 6.0, 0.0, 4.0, 2.0, 1.0, 5.0, 6.0, 11.0, 2.0, 0.0, 3.0, 5.555555556, 8.0, 5.0, 2.0, 1.0, 0.0, 1.0, 5.0, 1.0, 1.0, 3.0, 0.0, 6.0, 1.0, 0.0, 5.0, 5.0]
#
#  [0 nan 1 '1,5' '1,2']
# 45

# %% [markdown]
# # Formatting and Behavioral Checks on Closeness Ratings (IOS scores)

# %%
plt_df = df_ios[['Subject', 'ios_p', 'ios_fu_score','ios_computer']].copy()
plt_df.columns = ['Subject', 'Friend', 'Stranger', 'Computer']
plt_df = plt_df.melt(id_vars=['Subject'], value_vars=['Friend', 'Stranger', 'Computer'], var_name='Partner', value_name='Closeness')
fig_closeness = sns.barplot(x = 'Partner', y = 'Closeness',data=plt_df, ci=68,
                            palette=['tab:blue','orangered','gold'], edgecolor='black', linewidth=2)
#plt.savefig('../../istart-sharedreward/derivatives/Figures/mean_closeness.svg')
plt.show()

plt_df_anova = AnovaRM(plt_df, 'Closeness', 'Subject', within=['Partner'])
plt_df_results = plt_df_anova.fit()
#print(plt_df_anova.anova_table["Pr > F"][0])

print(plt_df_results.anova_table)
# Out:
#            F Value  Num DF  Den DF        Pr > F
# Partner  30.496029     2.0    54.0  1.369619e-09

# %%
print("Closeness Rating Stats:")
m = np.mean(df_ios['ios_p'])
sd = np.std(df_ios['ios_p'])
print("\nFriend Mean: %s, Friend SD: %s" %(m, sd))

m = np.mean(df_ios['ios_fu_score'])
sd = np.std(df_ios['ios_fu_score'])
print("\nStranger Mean: %s, Stranger SD: %s" %(m, sd))

m = np.mean(df_ios['ios_computer'])
sd = np.std(df_ios['ios_computer'])
print("\nComp Mean: %s, Comp SD: %s" %(m, sd))


subscreen = pd.read_excel('../derivatives/IOS_datediff.xlsx')
#subscreen['sub'].dir[subscreen.dir == subscreen.dir // 1]
#=subscreen['sub'].astype(int)
subscreen_df = pd.merge(df_ios[['sub', 'ios_diff_fu', 'ios_diff_stranger', 'ios_diff_computer']], subscreen, on='sub', how = 'left')
r,p = stats.pearsonr(subscreen_df['ios_diff_stranger'], subscreen_df['datediff'])
print("\nFollow-up delay vs [friend - stranger] closeness correlation \nr: %s ; p: %s" %(r,p))
r,p = stats.pearsonr(subscreen_df['ios_diff_computer'], subscreen_df['datediff'])
print("\nFollow-up delay vs [friend - computer] closeness correlation \nr: %s ; p: %s" %(r,p))
r,p = stats.pearsonr(subscreen_df['ios_diff_fu'], subscreen_df['datediff'])
print("\nFollow-up delay vs [stranger - computer] closeness correlation \nr: %s ; p: %s" %(r,p))
# Out:
# Closeness Rating Stats:
#
# Friend Mean: 4.642857142857143, Friend SD: 1.4196147795965564
#
# Stranger Mean: 2.2142857142857144, Stranger SD: 1.3720980508784675
#
# Comp Mean: 2.1785714285714284, Comp SD: 1.415565798757601
#
# Follow-up delay vs [friend - stranger] closeness correlation
# r: 0.18923548114788308 ; p: 0.3348260507838614
#
# Follow-up delay vs [friend - computer] closeness correlation
# r: 0.27628901000893025 ; p: 0.1546762727548823
#
# Follow-up delay vs [stranger - computer] closeness correlation
# r: 0.07187569692846538 ; p: 0.7162605437112066

# %% [markdown]
# # Histograms of substance use and reward sensitivity

# %%
plt.hist(df['SU'], edgecolor='k')
plt.show()
print('\t\t   Individual Differences - Substance Use\n')

plt.hist(df['RS'], edgecolor='k')
plt.show()
print('\t\t   Individual Differences - Reward Sensitivity\n')

plt.hist(df['RS_square'], edgecolor='k')
plt.show()
print('\t\t   Individual Differences - Reward Sensitivity Squared\n')
# Out:
# 		   Individual Differences - Substance Use
# 		   Individual Differences - Reward Sensitivity
# 		   Individual Differences - Reward Sensitivity Squared

# %% [markdown]
# ### Preliminary Checks of independent relations between VS-rFFA activation and individual difference measures (full linear regressions in Rstudio code)

# %%
r,p = stats.pearsonr(df['ppi_C16_rew_F-C_z1_main-effect_cluster1_type-ppi_seed-VS_thr5_cope-16'], df['RS'])
print("Reward Sensitivity correlation with VS to FFA connectivity when winning with Friend v Computer \nr: %s ; p: %s" %(r,p))
fig=sns.lmplot(y="ppi_C16_rew_F-C_z1_main-effect_cluster1_type-ppi_seed-VS_thr5_cope-16",x="RS", data=df, order=1)
plt.show()
print(type(fig))

r,p = stats.pearsonr(df['ppi_C16_rew_F-C_z1_main-effect_cluster1_type-ppi_seed-VS_thr5_cope-16'], df['SU'])
print("Substance Use correlation with VS to FFA connectivity when winning with Friend v Computer \nr: %s ; p: %s" %(r,p))
fig=sns.lmplot(y="ppi_C16_rew_F-C_z1_main-effect_cluster1_type-ppi_seed-VS_thr5_cope-16",x="SU", data=df, order=1)
plt.show()
print(type(fig))

r,p = stats.pearsonr(df['ppi_C16_rew_F-C_z1_main-effect_cluster1_type-ppi_seed-VS_thr5_cope-16'], df['SUxRS'])
print("RS*SU correlation with VS to FFA connectivity when winning with Friend v Computer \nr: %s ; p: %s" %(r,p))
fig=sns.lmplot(y="ppi_C16_rew_F-C_z1_main-effect_cluster1_type-ppi_seed-VS_thr5_cope-16",x="SUxRS", data=df, order=1)
plt.show()
print(type(fig))
# Out:
# Reward Sensitivity correlation with VS to FFA connectivity when winning with Friend v Computer
# r: 0.3746133442589799 ; p: 0.01123390641902428
# <class 'seaborn.axisgrid.FacetGrid'>
# Substance Use correlation with VS to FFA connectivity when winning with Friend v Computer
# r: 0.3594765837245274 ; p: 0.015297112260920136
# <class 'seaborn.axisgrid.FacetGrid'>
# RS*SU correlation with VS to FFA connectivity when winning with Friend v Computer
# r: 0.13618626962191308 ; p: 0.3723804261097893
# <class 'seaborn.axisgrid.FacetGrid'>

# %% [markdown]
# ## Checks for significance between Post-Scan Behavioral Ratings and RS

# %%
r,p = stats.pearsonr(df_psr['Win-Friend'], df_psr['RS'])
print("Win_Friend and RS - linear\nr: %s ; p: %s" %(r,p))
fig=sns.lmplot(y="Win-Friend",x="RS", data=df_psr, order=1)
plt.show()
print(type(fig))

r,p = stats.pearsonr(df_psr['Win-Friend'], df_psr['RS_square'])
print("Win_Friend and RS - curvilinear\nr: %s ; p: %s" %(r,p))
fig=sns.lmplot(y="Win-Friend",x="RS", data=df_psr, order=2)
plt.show()
print(type(fig))

r,p = stats.pearsonr(df_psr['Win-Comp'], df_psr['RS'])
print("Win_Comp and RS - linear\nr: %s ; p: %s" %(r,p))
fig=sns.lmplot(y="Win-Comp",x="RS", data=df_psr, order=1)
plt.show()
print(type(fig))

r,p = stats.pearsonr(df_psr['Win-Comp'], df_psr['RS_square'])
print("Win_Comp and RS - curvilinear\nr: %s ; p: %s" %(r,p))
fig=sns.lmplot(y="Win-Comp",x="RS", data=df_psr, order=2)
plt.show()
print(type(fig))
# Out:
# Win_Friend and RS - linear
# r: 0.19757954595168203 ; p: 0.20408434749314172
# <class 'seaborn.axisgrid.FacetGrid'>
# Win_Friend and RS - curvilinear
# r: 0.20501705002972334 ; p: 0.18722557635419232
# <class 'seaborn.axisgrid.FacetGrid'>
# Win_Comp and RS - linear
# r: -0.19540593796468303 ; p: 0.20920605221248326
# <class 'seaborn.axisgrid.FacetGrid'>
# Win_Comp and RS - curvilinear
# r: -0.18484154885278742 ; p: 0.23537405017761157
# <class 'seaborn.axisgrid.FacetGrid'>

# %% [markdown]
# ## Check for correlation between post-scan partner ratings and closeness (IOS)

# %%
r,p = stats.pearsonr(df_both['Win_F_S'], df_both['ios_diff_stranger'])
print("Difference b/w friend and stranger for: Post-Scan Ratings vs Closeness -  r: %s ; p: %s" %(r,p))

g=sns.lmplot(x='Win_F_S',y='ios_diff_stranger',data=df_ios, x_jitter=.1,y_jitter=.1)
plt.show()
print(type(g))

#df_ios['']
r,p = stats.pearsonr(df_both['Win_F_C'], df_both['ios_diff_computer'])
print("Difference b/w friend and computer for: Post-Scan Ratings vs Closeness -  r: %s ; p: %s" %(r,p))

g=sns.lmplot(x='Win_F_C',y='ios_diff_computer',data=df_both, x_jitter=.1,y_jitter=.1)
plt.show()
print(type(g))
# Out:
# Difference b/w friend and stranger for: Post-Scan Ratings vs Closeness -  r: -0.08156972693500016 ; p: 0.6858686472949822
# <class 'seaborn.axisgrid.FacetGrid'>
# Difference b/w friend and computer for: Post-Scan Ratings vs Closeness -  r: 0.03620400953500384 ; p: 0.8577191741691029
# <class 'seaborn.axisgrid.FacetGrid'>

# %% [markdown]
# # Recreate long-form Post-Scan Ratings dataframe from original data

# %%
os.chdir('../../istart/Shared_Reward')
#Make a list of all the SR Files
SR_flist=[os.path.join(root, f) for root, dirs, files in os.walk('logs') for f in files if 'SR-Rating' in f]

#Make a list of Dataframes
ratings_list=[]
for f in SR_flist:
    sub=re.search('sub(.*)_',f).group(1)
    if any(i.isdigit() for i in sub):
        tmp_df=pd.read_csv(f)
        tmp_df['sub']=sub
        if len(tmp_df)==6:
            ratings_list.append(tmp_df)
#Concatonate the DataFrames together
srpr_df=pd.concat(ratings_list)
srpr_df=srpr_df.reset_index(drop=True)

os.chdir('../../istart-sharedreward/derivatives')

#list(set(srpr_df['sub'].values) - set(df_psr['sub'].values))

#drop subjects who were not scanned and are not part of analyses
srpr_df['sub']=srpr_df['sub'].astype(int)
srpr_df_dropped=srpr_df[srpr_df['sub'].isin(list(df_psr['sub'].values))]

#calculate and display total subjects included in analysis
len(srpr_df_dropped)/6
# Out:
# 40.0

# %% [markdown]
# # Stats and ANOVA for post-scan partner ratings

# %%
print("Win Rating Stats:")
m = np.mean(df_psr['Win-Friend'])
sd = np.std(df_psr['Win-Friend'])
print("\nFriend Mean: %s, Friend SD: %s" %(m, sd))

m = np.mean(df_psr['Win-Stranger'])
sd = np.std(df_psr['Win-Stranger'])
print("\nStranger Mean: %s, Stranger SD: %s" %(m, sd))

m = np.mean(df_psr['Win-Comp'])
sd = np.std(df_psr['Win-Comp'])
print("\nComp Mean: %s, Comp SD: %s\n" %(m, sd))

print("Loss Rating Stats:")
m = np.mean(df_psr['Lose-Friend'])
sd = np.std(df_psr['Lose-Friend'])
print("\nFriend Mean: %s, Friend SD: %s" %(m, sd))

m = np.mean(df_psr['Lose-Stranger'])
sd = np.std(df_psr['Lose-Stranger'])
print("\nStranger Mean: %s, Stranger SD: %s" %(m, sd))

m = np.mean(df_psr['Lose-Comp'])
sd = np.std(df_psr['Lose-Comp'])
print("\nComp Mean: %s, Comp SD: %s\n" %(m, sd))

srpr_anova = AnovaRM(srpr_df_dropped, 'Rating', 'sub', within=['Partner', 'Trait'])
srpr_results = srpr_anova.fit()

print(srpr_results.anova_table)
# Out:
# Win Rating Stats:
#
# Friend Mean: 3.6511627906976742, Friend SD: 1.828504547567747
#
# Stranger Mean: 0.7674418604651163, Stranger SD: 2.419275398941204
#
# Comp Mean: 0.5348837209302325, Comp SD: 2.7648023370981454
#
# Loss Rating Stats:
#
# Friend Mean: -2.86046511627907, Friend SD: 2.3780135871933425
#
# Stranger Mean: -1.558139534883721, Stranger SD: 1.8464589061655077
#
# Comp Mean: -1.4651162790697674, Comp SD: 2.061257656387008
#
#                  F Value  Num DF  Den DF        Pr > F
# Partner         4.832693     2.0    78.0  1.050489e-02
# Trait          70.969367     1.0    39.0  2.594411e-10
# Partner:Trait  35.276959     2.0    78.0  1.225206e-11

# %% [markdown]
# ## Plot ANOVA results

# %%
Trait = {0:'Win', 1:'Lose'}
partner = {3:'Friend',2:'Stranger',1:'Computer'}
srpr_df_dropped['partner']=srpr_df_dropped['Partner'].map(partner)
srpr_df_dropped['Outcome']=srpr_df_dropped['Trait'].map(Trait)
srpr_df_dropped
fig = sns.barplot(y='Rating',x='Outcome',hue='partner', data=srpr_df_dropped, palette=['tab:blue','orangered','gold'], edgecolor='black', linewidth = 1)
#plt.savefig('../../istart-sharedreward/derivatives/Figures/partner_ratings_anova.svg')
plt.show()
# Out:
# C:\Users\tup54227\AppData\Local\Temp\ipykernel_13860\3126257670.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   srpr_df_dropped['partner']=srpr_df_dropped['Partner'].map(partner)
# C:\Users\tup54227\AppData\Local\Temp\ipykernel_13860\3126257670.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   srpr_df_dropped['Outcome']=srpr_df_dropped['Trait'].map(Trait)

# %% [markdown]
# ## Linear Regression with post-scan ratings and individual difference covariates (repeated and plotted in R)

# %%
ratings_lm = ols("Win_F_C ~ SU + RS + RS_square + SU:RS + SU:RS_square", data=df_psr).fit()
#df_psr.to_csv('../../istart-sharedreward/derivatives/df_psr.csv', index = False)

sm.stats.anova_lm(ratings_lm, typ=2)
ratings_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Win_F_C   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     1.805
# Date:                Sun, 01 Oct 2023   Prob (F-statistic):              0.136
# Time:                        19:47:18   Log-Likelihood:                -103.86
# No. Observations:                  43   AIC:                             219.7
# Df Residuals:                      37   BIC:                             230.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        3.1852      0.464      6.861      0.000       2.245       4.126
# SU               0.0405      0.363      0.112      0.912      -0.695       0.776
# RS               0.2198      0.166      1.322      0.194      -0.117       0.557
# RS_square        0.1403      0.068      2.068      0.046       0.003       0.278
# SU:RS           -0.1442      0.154     -0.936      0.355      -0.456       0.168
# SU:RS_square     0.0239      0.051      0.474      0.639      -0.078       0.126
# ==============================================================================
# Omnibus:                        0.006   Durbin-Watson:                   2.305
# Prob(Omnibus):                  0.997   Jarque-Bera (JB):                0.159
# Skew:                          -0.008   Prob(JB):                        0.924
# Kurtosis:                       2.702   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Outputting df of all covariates for PALM analysis of pre-registered hypotheses involving social closeness (IOS) and substance use interaction

# %%
iosxSU = df_ios.ios_diff_stranger * df_ios.SU
df_ios['iosxSU'] = iosxSU

iosxRS = df_ios.ios_diff_stranger * df_ios.RS
df_ios['iosxRS'] = iosxRS

iosxRS_square = df_ios.ios_diff_stranger * df_ios.RS_square
df_ios['iosxRS_square'] = iosxRS_square


ratings_lm = ols("pTPJ_R_P_F_S ~ ios_diff_stranger + SU + RS + RS_square + iosxSU + iosxRS + iosxRS_square + SUxRS + SUxRS_sq + tsnr + fd_mean", data=df_ios).fit()

sm.stats.anova_lm(ratings_lm, typ=2)
ratings_lm.summary()

#exporting matrix of regressors, and VS-pTPJ connectivity data for friend v stranger contrasts (col 1. reward; col 2. reward v punishment)

df_mat = df_ios[['sub','ios_diff_stranger','SU','RS','RS_square','iosxSU','iosxRS','iosxRS_square','SUxRS','SUxRS_sq','tsnr','fd_mean']].copy()
#df_mat.to_csv('../../istart-sharedreward/derivatives/palm_ios/df_mat.csv', index = False) #note: column for main effect added manually after export
df_palm_ppi = df_ios[['pTPJ_R_F_S','pTPJ_R_P_F_S']].copy()
#df_palm_ppi.to_csv('../../istart-sharedreward/derivatives/palm_ios/df_palm_ppi.csv', index = False, header = False)
# Out:
# C:\Users\tup54227\AppData\Local\Temp\ipykernel_13860\3514160331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ios['iosxSU'] = iosxSU
# C:\Users\tup54227\AppData\Local\Temp\ipykernel_13860\3514160331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ios['iosxRS'] = iosxRS
# C:\Users\tup54227\AppData\Local\Temp\ipykernel_13860\3514160331.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ios['iosxRS_square'] = iosxRS_square

# %% [markdown]
# # Outputting df of all VS-TPJ contrasts for Rstudio Analyses

# %%
df_TPJ = df[['sub','aTPJ_R_P_F_C', 'aTPJ_R_P_F_S','pTPJ_R_P_F_C','pTPJ_R_P_F_S']].copy()
#df_TPJ.to_excel('../../istart-sharedreward/derivatives/df_TPJ.xlsx', index = False)
len(df_TPJ)
# Out:
# 45

# %%
df['AUD
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AUDIT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13860\3900233287.py in <module>
# ----> 1 df['AUDIT']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'AUDIT'
